# %% [markdown]
# # Small Selected Alt Experiment
#
# Kontrolowany test malej liczby cech na istniejacym `session_aligned` dataset:
# - `price_only`
# - `price_plus_google_small`
# - `price_plus_reddit_small`
# - `price_plus_google_reddit_small`
#
# Cel: sprawdzic, czy problemem byl glownie nadmiar cech i overfitting.

# %%
from small_selected_alt_experiment import run_small_selected_alt_experiment

result = run_small_selected_alt_experiment()
result["metrics"].query("split == 'test'").sort_values(["ticker", "model_name", "feature_set"]).reset_index(drop=True)
# Out:
#    ticker              model_name                     feature_set split  \
# 0    AAPL  hist_gradient_boosting                      price_only  test
# 1    AAPL  hist_gradient_boosting  price_plus_google_reddit_small  test
# 2    AAPL  hist_gradient_boosting         price_plus_google_small  test
# 3    AAPL  hist_gradient_boosting         price_plus_reddit_small  test
# 4    AAPL                  logreg                      price_only  test
# 5    AAPL                  logreg  price_plus_google_reddit_small  test
# 6    AAPL                  logreg         price_plus_google_small  test
# 7    AAPL                  logreg         price_plus_reddit_small  test
# 8    AAPL           random_forest                      price_only  test
# 9    AAPL           random_forest  price_plus_google_reddit_small  test
# 10   AAPL           random_forest         price_plus_google_small  test
# 11   AAPL           random_forest         price_plus_reddit_small  test
# ...

# %%
result["test_deltas"].sort_values(["ticker", "model_name", "feature_set"]).reset_index(drop=True)
# Out:
#    ticker              model_name                     feature_set  \
# 0    AAPL  hist_gradient_boosting  price_plus_google_reddit_small
# 1    AAPL  hist_gradient_boosting         price_plus_google_small
# 2    AAPL  hist_gradient_boosting         price_plus_reddit_small
# 3    AAPL                  logreg  price_plus_google_reddit_small
# 4    AAPL                  logreg         price_plus_google_small
# 5    AAPL                  logreg         price_plus_reddit_small
# 6    AAPL           random_forest  price_plus_google_reddit_small
# 7    AAPL           random_forest         price_plus_google_small
# 8    AAPL           random_forest         price_plus_reddit_small
# 9     ALL  hist_gradient_boosting  price_plus_google_reddit_small
# 10    ALL  hist_gradient_boosting         price_plus_google_small
# 11    ALL  hist_gradient_boosting         price_plus_reddit_small
# 12    ALL                  logreg  price_plus_google_reddit_small
# ...

# %%
result["metrics"].query("split == 'test'").pivot_table(
    index=["ticker", "model_name"],
    columns="feature_set",
    values="balanced_accuracy",
)
# Out:
# feature_set                    price_only  price_plus_google_reddit_small  \
# ticker model_name
# AAPL   hist_gradient_boosting    0.533990                        0.542857
#        logreg                    0.511576                        0.524384
#        random_forest             0.505665                        0.563054
# ALL    hist_gradient_boosting    0.558569                        0.556109
#        logreg                    0.560844                        0.573203
#        random_forest             0.566009                        0.570282
# TSLA   hist_gradient_boosting    0.581675                        0.568411
#        logreg                    0.609555                        0.621592
#        random_forest             0.625276                        0.576885
#
# feature_set                    price_plus_google_small  \
# ticker model_name
# AAPL   hist_gradient_boosting                 0.528325
#        logreg                                 0.500000
# ...

# %%
result["metrics"].query("split == 'test'").pivot_table(
    index=["ticker", "model_name"],
    columns="feature_set",
    values="roc_auc",
)
# Out:
# feature_set                    price_only  price_plus_google_reddit_small  \
# ticker model_name
# AAPL   hist_gradient_boosting    0.552709                        0.553695
#        logreg                    0.497044                        0.551232
#        random_forest             0.538177                        0.572906
# ALL    hist_gradient_boosting    0.556232                        0.573449
#        logreg                    0.559860                        0.585316
#        random_forest             0.579413                        0.584087
# TSLA   hist_gradient_boosting    0.569885                        0.600590
#        logreg                    0.618767                        0.598870
#        random_forest             0.611152                        0.599853
#
# feature_set                    price_plus_google_small  \
# ticker model_name
# AAPL   hist_gradient_boosting                 0.536946
#        logreg                                 0.510591
# ...

# %%
result["metrics"].query("split == 'train'").pivot_table(
    index=["ticker", "model_name"],
    columns="feature_set",
    values="balanced_accuracy",
)
# Out:
# feature_set                    price_only  price_plus_google_reddit_small  \
# ticker model_name
# AAPL   hist_gradient_boosting    0.874563                        0.943695
#        logreg                    0.535277                        0.542529
#        random_forest             0.877369                        0.889541
# ALL    hist_gradient_boosting    0.891913                        0.948316
#        logreg                    0.544684                        0.573850
#        random_forest             0.837600                        0.881679
# TSLA   hist_gradient_boosting    0.906619                        0.951801
#        logreg                    0.552299                        0.603701
#        random_forest             0.795527                        0.873027
#
# feature_set                    price_plus_google_small  \
# ticker model_name
# AAPL   hist_gradient_boosting                 0.905722
#        logreg                                 0.540780
# ...
