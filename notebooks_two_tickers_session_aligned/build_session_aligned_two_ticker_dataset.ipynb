# %% [markdown]
# # Build Session-Aligned Two-Ticker Dataset
#
# Buduje nowa baze, w ktorej alt-data sa agregowane do sesji giełdowej i zapisywane do osobnego katalogu.

# %%
from session_aligned_dataset_builder import build_two_ticker_session_aligned_dataset

result = build_two_ticker_session_aligned_dataset()
result["summary"]
# Out:
#   ticker  rows    date_min    date_max  n_positive  n_negative  n_neutral
# 0   AAPL   752  2023-01-03  2025-12-31         361         291         99
# 1   TSLA   752  2023-01-03  2025-12-31         367         343         41
