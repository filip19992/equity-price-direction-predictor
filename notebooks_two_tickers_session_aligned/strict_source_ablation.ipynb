# %% [markdown]
# # Session-Aligned Strict Source Ablation
#
# Osobne ablation dla Google Trends, GDELT, Reddit sentiment i Reddit attention na nowej bazie session-aligned.

# %%
from strict_source_ablation_experiment import run_strict_source_ablation_experiment

result = run_strict_source_ablation_experiment()
result["metrics"].query("split == 'test'").sort_values(["balanced_accuracy"])
# Out:
#    ticker              model_name                  feature_set split  n_rows  \
# 22   AAPL                 svm_rbf     price_plus_google_trends  test     128
# 20   AAPL                 svm_rbf                   price_only  test     128
# 17   AAPL           random_forest     price_plus_google_trends  test     128
# 3    AAPL  hist_gradient_boosting  price_plus_reddit_attention  test     128
# 18   AAPL           random_forest  price_plus_reddit_attention  test     128
# 71   TSLA                 svm_rbf             price_plus_gdelt  test     128
# 21   AAPL                 svm_rbf             price_plus_gdelt  test     128
# 11   AAPL               mlp_small             price_plus_gdelt  test     128
# 62   TSLA               mlp_small     price_plus_google_trends  test     128
# 24   AAPL                 svm_rbf  price_plus_reddit_sentiment  test     128
# 73   TSLA                 svm_rbf  price_plus_reddit_attention  test     128
# ...

# %%
result["cv_fold_deltas"].groupby(["ticker", "model_name", "feature_set_alt"], as_index=False)[["delta_balanced_accuracy", "delta_roc_auc"]].mean().sort_values(["ticker", "delta_balanced_accuracy"], ascending=[True, False])
# Out:
#    ticker              model_name              feature_set_alt  \
# 1    AAPL  hist_gradient_boosting     price_plus_google_trends
# 2    AAPL  hist_gradient_boosting  price_plus_reddit_attention
# 15   AAPL           random_forest  price_plus_reddit_sentiment
# 6    AAPL                  logreg  price_plus_reddit_attention
# 0    AAPL  hist_gradient_boosting             price_plus_gdelt
# 3    AAPL  hist_gradient_boosting  price_plus_reddit_sentiment
# 9    AAPL               mlp_small     price_plus_google_trends
# 5    AAPL                  logreg     price_plus_google_trends
# 7    AAPL                  logreg  price_plus_reddit_sentiment
# 16   AAPL                 svm_rbf             price_plus_gdelt
# 14   AAPL           random_forest  price_plus_reddit_attention
# 13   AAPL           random_forest     price_plus_google_trends
# 4    AAPL                  logreg             price_plus_gdelt
# 11   AAPL               mlp_small  price_plus_reddit_sentiment
# ...
