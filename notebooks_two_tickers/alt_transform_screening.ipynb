# %% [markdown]
# # Alt Transform Screening
#
# Screening lagow i przeksztalcen alt-data na trainie i walk-forward foldach.

# %%
from alt_transform_screening_experiment import run_alt_transform_screening_experiment

result = run_alt_transform_screening_experiment()
result["selected_features"].query("selected_final").sort_values(["ticker", "selection_rank"])
# Out:
# C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\notebooks_two_tickers\alt_transform_screening_experiment.py:135: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[feature_name] = transformed
# C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\notebooks_two_tickers\alt_transform_screening_experiment.py:135: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[feature_name] = transformed
# ...

# %%
result["feature_metrics"].sort_values(["ticker", "selection_score"], ascending=[True, False]).groupby("ticker").head(20)
# Out:
#     ticker                                   feature_name      source_group  \
# 99    AAPL                  reddit_sentiment__gap__delta1  reddit_sentiment
# 109   AAPL              reddit_sentiment__gap__surprise20  reddit_sentiment
# 105   AAPL                   reddit_sentiment__gap__level  reddit_sentiment
# 121   AAPL                reddit_sentiment__vader__delta1  reddit_sentiment
# 96    AAPL               reddit_sentiment__finbert__roll5  reddit_sentiment
# 102   AAPL               reddit_sentiment__gap__gap_roll5  reddit_sentiment
# 125   AAPL                  reddit_sentiment__vader__lag2  reddit_sentiment
# 101   AAPL               reddit_sentiment__gap__gap_roll3  reddit_sentiment
# 32    AAPL                   gdelt__sentiment__surprise20             gdelt
# 107   AAPL                   reddit_sentiment__gap__roll5  reddit_sentiment
# 114   AAPL                   reddit_sentiment__mean__lag2  reddit_sentiment
# ...
