# %% [markdown]
# # Session-Aligned Price vs Alt Baseline
#
# Pierwszy baseline dla nowej bazy session-aligned.

# %%
from price_alt_baseline_experiment import run_baseline_experiment

result = run_baseline_experiment()
result["metrics"].query("split == 'test'").sort_values(["balanced_accuracy"])
# Out:
#        model_name     feature_set split ticker  n_rows  n_features  accuracy  \
# 12         logreg        alt_only  test   TSLA     128          19  0.437500
# 3   random_forest        alt_only  test   AAPL     128          19  0.468750
# 1          logreg      price_only  test   AAPL     128          15  0.507812
# 6          logreg        alt_only  test    ALL     256          19  0.488281
# 5   random_forest  price_plus_alt  test   AAPL     128          33  0.507812
# 9   random_forest        alt_only  test    ALL     256          19  0.500000
# 2          logreg  price_plus_alt  test   AAPL     128          33  0.500000
# 11  random_forest  price_plus_alt  test    ALL     256          33  0.515625
# 8          logreg  price_plus_alt  test    ALL     256          33  0.507812
# 17  random_forest  price_plus_alt  test   TSLA     128          33  0.523438
# 14         logreg  price_plus_alt  test   TSLA     128          33  0.515625
# ...
