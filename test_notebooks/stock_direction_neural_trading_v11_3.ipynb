# %% [markdown]
# # Stock Direction v11.3: Neural Ranking Model for Peak Capture
#
# This notebook reframes the problem as an **event-ranking** task instead of standard daily classification:
#
# - target the days with **large positive next-day returns**,
# - fit a small MLP that scores the probability of a peak-up event,
# - select the **top-ranked fraction of days** in each validation/test window,
# - evaluate the model with:
#   - `precision@budget`,
#   - `recall@budget`,
#   - average return of selected days,
#   - trading performance of the selected longs.
#
# The validation regime stays strict:
#
# - rolling `12M train / 3M validation`,
# - untouched final `6M` holdout.

# %%
from itertools import product
from pathlib import Path
import ast
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import mutual_info_classif
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 4)

RANDOM_STATE = 42
FINAL_HOLDOUT_MONTHS = 6
TRAIN_MONTHS = 12
VAL_MONTHS = 3
STEP_MONTHS = 1
ONE_WAY_COST = 0.0005
MIN_POSITIVE_SAMPLES = 25
STABILITY_TOP_N = 15

UP_MOVE_BANDS = [0.02, 0.025, 0.03]
TOP_K_VALUES = [8, 12]
HIDDEN_CHOICES = [(8,), (16,), (16, 8)]
ALPHA_VALUES = [0.001, 0.01]
LR_VALUES = [0.001]
RANK_BUDGET_PCTS = [0.05, 0.08, 0.10, 0.15]

# %%
def rank_features_mi(X_train, y_train):
    if X_train.empty:
        return pd.DataFrame(columns=["feature", "mi", "rank"])
    imp = SimpleImputer(strategy="median")
    X_i = imp.fit_transform(X_train)
    mi = mutual_info_classif(X_i, y_train.astype(int), random_state=RANDOM_STATE)
    ranked = pd.DataFrame({"feature": X_train.columns, "mi": mi}).sort_values(
        ["mi", "feature"], ascending=[False, True]
    ).reset_index(drop=True)
    ranked["rank"] = np.arange(1, len(ranked) + 1)
    return ranked


def fit_mlp(train_X, train_y, selected_cols, hidden_layers, alpha_value, learning_rate):
    model = Pipeline(
        steps=[
            ("imp", SimpleImputer(strategy="median")),
            ("sc", StandardScaler()),
            (
                "clf",
                MLPClassifier(
                    hidden_layer_sizes=tuple(hidden_layers),
                    activation="relu",
                    solver="adam",
                    alpha=float(alpha_value),
                    learning_rate_init=float(learning_rate),
                    batch_size=32,
                    max_iter=500,
                    early_stopping=True,
                    n_iter_no_change=20,
                    validation_fraction=0.15,
                    random_state=RANDOM_STATE,
                ),
            ),
        ]
    )
    model.fit(train_X[selected_cols], train_y)
    return model


def build_fixed_windows(df, train_months, test_months, step_months):
    windows = []
    min_date = df["date"].min().normalize()
    max_date = df["date"].max().normalize()
    test_start = (min_date + pd.DateOffset(months=train_months)).normalize()
    window_id = 1

    while test_start <= max_date:
        train_start = (test_start - pd.DateOffset(months=train_months)).normalize()
        test_end = (test_start + pd.DateOffset(months=test_months)).normalize()

        tr = df[(df["date"] >= train_start) & (df["date"] < test_start)].copy()
        te = df[(df["date"] >= test_start) & (df["date"] < test_end)].copy()
        if te.empty:
            break
        if not tr.empty:
            windows.append(
                {
                    "window_id": window_id,
                    "train_start": train_start,
                    "train_end": test_start - pd.Timedelta(days=1),
                    "test_start": test_start,
                    "test_end": min(test_end - pd.Timedelta(days=1), te["date"].max()),
                    "train_df": tr,
                    "test_df": te,
                }
            )
            window_id += 1
        test_start = (test_start + pd.DateOffset(months=step_months)).normalize()

    return windows


def compute_stability_table(windows, feature_cols, up_move_band, top_n):
    rankings = []
    valid_windows = 0

    for window in windows:
        tr = window["train_df"]
        y = (tr["future_return_1d"] > up_move_band).astype(int).to_numpy()
        if y.sum() < MIN_POSITIVE_SAMPLES or len(np.unique(y)) < 2:
            continue
        ranked = rank_features_mi(tr[feature_cols], y)
        if ranked.empty:
            continue
        ranked["window_id"] = window["window_id"]
        rankings.append(ranked)
        valid_windows += 1

    if not rankings or valid_windows == 0:
        return pd.DataFrame(
            columns=[
                "up_move_band",
                "feature",
                "freq_top_n",
                "coverage",
                "mean_rank",
                "mean_mi",
                "top_n_hits",
                "n_windows",
            ]
        )

    ranking_df = pd.concat(rankings, ignore_index=True)
    summary = ranking_df.groupby("feature").agg(
        mean_rank=("rank", "mean"),
        mean_mi=("mi", "mean"),
        appearances=("window_id", "nunique"),
        top_n_hits=("rank", lambda s: int((s <= top_n).sum())),
    ).reset_index()
    summary["up_move_band"] = up_move_band
    summary["n_windows"] = valid_windows
    summary["coverage"] = summary["appearances"] / valid_windows
    summary["freq_top_n"] = summary["top_n_hits"] / valid_windows
    summary = summary.sort_values(
        ["freq_top_n", "mean_rank", "mean_mi", "feature"],
        ascending=[False, True, False, True],
    ).reset_index(drop=True)
    return summary[["up_move_band", "feature", "freq_top_n", "coverage", "mean_rank", "mean_mi", "top_n_hits", "n_windows"]]


def top_features_from_stability(stability_df, top_k):
    if stability_df.empty:
        return []
    ordered = stability_df["feature"].tolist()
    return ordered[: min(int(top_k), len(ordered))]


def fit_peak_model(train_df, stability_df, top_k, hidden_layers, alpha_value, learning_rate, up_move_band):
    y_peak = (train_df["future_return_1d"] > up_move_band).astype(int).to_numpy()
    if y_peak.sum() < MIN_POSITIVE_SAMPLES or len(np.unique(y_peak)) < 2:
        return None

    selected_cols = top_features_from_stability(stability_df, top_k)
    if not selected_cols:
        return None

    model = fit_mlp(
        train_df,
        y_peak,
        selected_cols,
        hidden_layers=hidden_layers,
        alpha_value=alpha_value,
        learning_rate=learning_rate,
    )
    return {
        "model": model,
        "selected_cols": selected_cols,
        "hidden_layers": tuple(hidden_layers),
        "alpha_value": float(alpha_value),
        "learning_rate": float(learning_rate),
        "up_move_band": float(up_move_band),
    }


def score_peak_probabilities(bundle, frame):
    return bundle["model"].predict_proba(frame[bundle["selected_cols"]])[:, 1]


def select_top_ranked_signals(probabilities, budget_pct):
    probs = np.asarray(probabilities, dtype=float)
    n = len(probs)
    if n == 0:
        return np.zeros(0, dtype=int), np.zeros(0, dtype=int)
    n_select = max(1, int(np.ceil(n * float(budget_pct))))
    order = np.argsort(probs)[::-1]
    signal = np.zeros(n, dtype=int)
    signal[order[:n_select]] = 1
    rank = np.empty(n, dtype=int)
    rank[order] = np.arange(1, n + 1)
    return signal, rank


def backtest_long_only(future_returns, signal, one_way_cost):
    r = np.asarray(future_returns, dtype=float)
    s = np.asarray(signal, dtype=int)
    trade_mask = s == 1
    strat_ret = np.zeros(len(s), dtype=float)
    strat_ret[trade_mask] = r[trade_mask] - 2.0 * one_way_cost
    return strat_ret, trade_mask, s


def perf_stats_ranked(strat_ret, trade_mask, signal, future_returns, up_move_band):
    strat_ret = np.asarray(strat_ret, dtype=float)
    trade_mask = np.asarray(trade_mask, dtype=bool)
    signal = np.asarray(signal, dtype=int)
    future_returns = np.asarray(future_returns, dtype=float)

    equity = np.cumprod(1 + strat_ret)
    running_max = np.maximum.accumulate(equity)
    drawdown = equity / running_max - 1

    sharpe = 0.0
    if len(strat_ret) > 1 and np.std(strat_ret, ddof=1) > 0:
        sharpe = float(np.sqrt(252) * np.mean(strat_ret) / np.std(strat_ret, ddof=1))

    n_active = int(trade_mask.sum())
    hit_rate = float(np.mean(strat_ret[trade_mask] > 0)) if n_active else np.nan

    big_up_mask = future_returns > up_move_band
    big_up_days = int(big_up_mask.sum())
    big_up_captured = int(np.sum(big_up_mask & trade_mask))
    recall_at_budget = float(big_up_captured / big_up_days) if big_up_days else np.nan
    precision_at_budget = float(np.mean(big_up_mask[trade_mask])) if n_active else np.nan

    active_returns = future_returns[trade_mask]
    return {
        "cum_return": float(equity[-1] - 1),
        "sharpe": sharpe,
        "max_drawdown": float(drawdown.min()),
        "avg_daily_return": float(np.mean(strat_ret)),
        "active_days": n_active,
        "active_pct": float(np.mean(trade_mask)),
        "entries_exits": float(n_active * 2),
        "hit_rate_active": hit_rate,
        "selected_mean_return": float(np.mean(active_returns)) if active_returns.size else np.nan,
        "selected_median_return": float(np.median(active_returns)) if active_returns.size else np.nan,
        "big_up_days": big_up_days,
        "big_up_captured": big_up_captured,
        "recall_at_budget": recall_at_budget,
        "precision_at_budget": precision_at_budget,
    }


cwd = Path.cwd().resolve()
project_root = next(
    (
        base
        for base in [cwd, *cwd.parents]
        if (base / "data" / "equity_data" / "model_data").exists()
    ),
    None,
)
if project_root is None:
    raise FileNotFoundError(f"Could not locate project root from cwd={cwd}")

source_path = project_root / "data" / "equity_data" / "model_data" / "stock_direction_dataset_v11_1_lagged.csv"
if not source_path.exists():
    raise FileNotFoundError("No v11.1 lagged dataset found for v11.3.")

df = pd.read_csv(source_path)
df["date"] = pd.to_datetime(df["date"], errors="coerce")
df = df.dropna(subset=["date"]).sort_values("date").reset_index(drop=True)
for c in df.columns:
    if c != "date":
        df[c] = pd.to_numeric(df[c], errors="coerce")

df = df.replace([np.inf, -np.inf], np.nan)
df["future_return_1d"] = pd.to_numeric(df["future_return_1d"], errors="coerce")
rows_before = len(df)
df = df.dropna(subset=["future_return_1d"]).reset_index(drop=True)
df["abs_future_return_1d"] = df["future_return_1d"].abs()
dropped_rows = rows_before - len(df)

feature_cols = [c for c in df.columns if c not in ["date", "future_return_1d", "y_dir", "abs_future_return_1d"]]

holdout_start = df["date"].max() - pd.DateOffset(months=FINAL_HOLDOUT_MONTHS)
train_pool = df[df["date"] < holdout_start].copy()
final_test_df = df[df["date"] >= holdout_start].copy()
rolling_windows = build_fixed_windows(train_pool, TRAIN_MONTHS, VAL_MONTHS, STEP_MONTHS)
final_train_df = train_pool.copy()

stability_tables = {}
stability_rows = []
for band in UP_MOVE_BANDS:
    band_df = compute_stability_table(rolling_windows, feature_cols, band, STABILITY_TOP_N)
    stability_tables[band] = band_df
    stability_rows.append(band_df)
feature_stability_df = pd.concat(stability_rows, ignore_index=True) if stability_rows else pd.DataFrame()

configs_per_model = (
    len(UP_MOVE_BANDS)
    * len(TOP_K_VALUES)
    * len(HIDDEN_CHOICES)
    * len(ALPHA_VALUES)
    * len(LR_VALUES)
    * len(RANK_BUDGET_PCTS)
)

output_dir = project_root / "data" / "equity_data" / "model_data"
output_dir.mkdir(parents=True, exist_ok=True)

base_out_path = output_dir / "stock_direction_dataset_v11_3_base.csv"
stability_out_path = output_dir / "stock_direction_v11_3_feature_stability.csv"
df.to_csv(base_out_path, index=False)
feature_stability_df.to_csv(stability_out_path, index=False)

print(f"Current working directory: {cwd}")
print(f"Project root: {project_root}")
print(f"Using source dataset: {source_path}")
print(f"Rows after cleaning: {len(df)}")
print(f"Rows dropped due to missing target: {dropped_rows}")
print(f"Feature columns: {len(feature_cols)}")
print(f"Rolling windows: {len(rolling_windows)}")
print(f"Final train rows: {len(final_train_df)}")
print(f"Final holdout rows: {len(final_test_df)}")
print(f"Total v11.3 candidates: {configs_per_model}")
print(f"Saved base dataset to {base_out_path}")
print(f"Saved feature stability to {stability_out_path}")
for band in UP_MOVE_BANDS:
    print(f'Band {band}: stability rows={len(stability_tables[band])}')
display(feature_stability_df.head(20))
# Out:
# Current working directory: C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\notebooks
# Project root: C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code
# Using source dataset: C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\data\equity_data\model_data\stock_direction_dataset_v11_1_lagged.csv
# Rows after cleaning: 750
# Rows dropped due to missing target: 0
# Feature columns: 114
# Rolling windows: 18
# Final train rows: 623
# Final holdout rows: 127
# Total v11.3 candidates: 144
# Saved base dataset to C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\data\equity_data\model_data\stock_direction_dataset_v11_3_base.csv
# Saved feature stability to C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\data\equity_data\model_data\stock_direction_v11_3_feature_stability.csv
# Band 0.02: stability rows=114
# Band 0.025: stability rows=114
# Band 0.03: stability rows=114
#     up_move_band                     feature  freq_top_n  coverage  mean_rank  \
# 0           0.02              subm_posts_z20    0.611111       1.0  18.000000
# 1           0.02           volume_z20_delta5    0.611111       1.0  21.666667
# 2           0.02               ret_1d_delta1    0.611111       1.0  26.111111
# 3           0.02      realized_vol_5d_delta5    0.500000       1.0  17.000000
# 4           0.02      volume_vs_sma_20d_lag5    0.444444       1.0  27.666667
# 5           0.02                      ret_5d    0.444444       1.0  34.000000
# 6           0.02        subm_posts_z20_mean3    0.388889       1.0  29.166667
# 7           0.02                 ret_1d_lag2    0.388889       1.0  35.555556
# 8           0.02     volume_vs_sma_20d_mean3    0.388889       1.0  44.555556
# 9           0.02       subm_posts_z20_delta1    0.388889       1.0  46.555556
# 10          0.02                 ret_1d_lag5    0.333333       1.0  27.277778
# 11          0.02             price_vs_sma_5d    0.333333       1.0  37.277778
# 12          0.02           subm_finbert_mean    0.333333       1.0  37.888889
# 13          0.02        realized_vol_5d_lag1    0.333333       1.0  41.944444
# 14          0.02    volume_vs_sma_20d_delta5    0.333333       1.0  63.277778
# 15          0.02    comm_finbert_mean_delta1    0.277778       1.0  31.777778
# 16          0.02  gdelt_sentiment_score_lag1    0.277778       1.0  32.444444
# 17          0.02                 ret_2d_lag2    0.277778       1.0  41.888889
# 18          0.02        price_vs_sma_5d_lag5    0.277778       1.0  50.055556
# 19          0.02       realized_vol_5d_mean5    0.277778       1.0  55.055556
#
#      mean_mi  top_n_hits  n_windows
# 0   0.035504          11         18
# 1   0.032502          11         18
# 2   0.027874          11         18
# 3   0.028926           9         18
# 4   0.026330           8         18
# 5   0.021634           8         18
# 6   0.027689           7         18
# 7   0.016196           7         18
# 8   0.019196           7         18
# 9   0.014229           7         18
# 10  0.020156           6         18
# 11  0.015460           6         18
# 12  0.016924           6         18
# 13  0.018483           6         18
# 14  0.028885           6         18
# 15  0.015470           5         18
# 16  0.018040           5         18
# 17  0.015327           5         18
# 18  0.012256           5         18
# 19  0.014487           5         18

# %%
search_rows = []
config_counter = 0

print(f"Starting v11.3 rolling search with {configs_per_model} candidates")

for (
    up_move_band,
    top_k,
    hidden_layers,
    alpha_value,
    learning_rate,
    rank_budget_pct,
) in product(
    UP_MOVE_BANDS,
    TOP_K_VALUES,
    HIDDEN_CHOICES,
    ALPHA_VALUES,
    LR_VALUES,
    RANK_BUDGET_PCTS,
):
    config_counter += 1
    print(
        f"[Config {config_counter}/{configs_per_model}] "
        f"band={up_move_band}, top_k={top_k}, hidden={hidden_layers}, "
        f"alpha={alpha_value}, lr={learning_rate}, budget={rank_budget_pct}"
    )

    stability_df = stability_tables[up_move_band]
    if stability_df.empty:
        print("  no stability table for this band")
        continue

    window_stats = []
    invalid = False

    for window in rolling_windows:
        if window["window_id"] == 1 or window["window_id"] == len(rolling_windows) or window["window_id"] % 5 == 0:
            print(f"  window {window['window_id']}/{len(rolling_windows)}")

        tr = window["train_df"]
        te = window["test_df"]
        bundle = fit_peak_model(
            train_df=tr,
            stability_df=stability_df,
            top_k=top_k,
            hidden_layers=hidden_layers,
            alpha_value=alpha_value,
            learning_rate=learning_rate,
            up_move_band=up_move_band,
        )
        if bundle is None:
            invalid = True
            break

        p_peak = score_peak_probabilities(bundle, te)
        signal, prob_rank = select_top_ranked_signals(p_peak, budget_pct=rank_budget_pct)
        strat_ret, trade_mask, signal_exec = backtest_long_only(
            te["future_return_1d"].to_numpy(),
            signal,
            ONE_WAY_COST,
        )
        stats = perf_stats_ranked(
            strat_ret,
            trade_mask,
            signal_exec,
            te["future_return_1d"].to_numpy(),
            up_move_band=up_move_band,
        )
        window_stats.append(stats)

    if invalid or not window_stats:
        print("  no valid rolling result for this config")
        continue

    mean_cum = float(np.mean([s["cum_return"] for s in window_stats]))
    median_cum = float(np.median([s["cum_return"] for s in window_stats]))
    mean_sharpe = float(np.mean([s["sharpe"] for s in window_stats]))
    mean_drawdown = float(np.mean([s["max_drawdown"] for s in window_stats]))
    mean_active = float(np.mean([s["active_pct"] for s in window_stats]))
    hit_values = [s["hit_rate_active"] for s in window_stats if not np.isnan(s["hit_rate_active"])]
    mean_hit = float(np.mean(hit_values)) if hit_values else 0.5
    precision_values = [s["precision_at_budget"] for s in window_stats if not np.isnan(s["precision_at_budget"])]
    mean_precision = float(np.mean(precision_values)) if precision_values else 0.0
    recall_values = [s["recall_at_budget"] for s in window_stats if not np.isnan(s["recall_at_budget"])]
    mean_recall = float(np.mean(recall_values)) if recall_values else 0.0
    mean_selected_return = float(np.mean([s["selected_mean_return"] for s in window_stats if not np.isnan(s["selected_mean_return"])]))
    profitable_pct = float(np.mean([s["cum_return"] > 0 for s in window_stats]))

    score = (
        0.25 * mean_precision
        + 0.25 * mean_recall
        + 0.20 * mean_sharpe
        + 0.15 * mean_selected_return * 10.0
        + 0.15 * profitable_pct
        - 0.10 * abs(mean_drawdown)
    )

    search_rows.append(
        {
            "up_move_band": up_move_band,
            "top_k": top_k,
            "hidden_layers": str(tuple(hidden_layers)),
            "alpha_value": alpha_value,
            "learning_rate": learning_rate,
            "rank_budget_pct": rank_budget_pct,
            "rolling_score": score,
            "rolling_mean_cum_return": mean_cum,
            "rolling_median_cum_return": median_cum,
            "rolling_mean_sharpe": mean_sharpe,
            "rolling_mean_drawdown": mean_drawdown,
            "rolling_mean_active_pct": mean_active,
            "rolling_mean_hit_rate": mean_hit,
            "rolling_mean_precision_at_budget": mean_precision,
            "rolling_mean_recall_at_budget": mean_recall,
            "rolling_mean_selected_return": mean_selected_return,
            "rolling_profitable_window_pct": profitable_pct,
            "n_windows": len(window_stats),
        }
    )
    print(
        f"  done: score={score:.4f}, precision={mean_precision:.4f}, "
        f"recall={mean_recall:.4f}, sel_ret={mean_selected_return:.4f}, active={mean_active:.4f}"
    )

search_df = pd.DataFrame(search_rows).sort_values("rolling_score", ascending=False).reset_index(drop=True)
if search_df.empty:
    raise RuntimeError("No search results generated for v11.3")

search_path = output_dir / "stock_direction_v11_3_search_results.csv"
search_df.to_csv(search_path, index=False)
display(search_df.head(10))

best_cfg = search_df.iloc[0].to_dict()
print("Best v11.3 config:", best_cfg)

print("Re-running best v11.3 config across rolling windows...")
rolling_best_rows = []
best_band = float(best_cfg["up_move_band"])
best_stability_df = stability_tables[best_band]
for window in rolling_windows:
    if window["window_id"] == 1 or window["window_id"] == len(rolling_windows) or window["window_id"] % 5 == 0:
        print(f"  best-config window {window['window_id']}/{len(rolling_windows)}")

    tr = window["train_df"]
    te = window["test_df"]
    bundle = fit_peak_model(
        train_df=tr,
        stability_df=best_stability_df,
        top_k=int(best_cfg["top_k"]),
        hidden_layers=ast.literal_eval(best_cfg["hidden_layers"]),
        alpha_value=float(best_cfg["alpha_value"]),
        learning_rate=float(best_cfg["learning_rate"]),
        up_move_band=best_band,
    )
    p_peak = score_peak_probabilities(bundle, te)
    signal, prob_rank = select_top_ranked_signals(p_peak, budget_pct=float(best_cfg["rank_budget_pct"]))
    strat_ret, trade_mask, signal_exec = backtest_long_only(
        te["future_return_1d"].to_numpy(),
        signal,
        ONE_WAY_COST,
    )
    stats = perf_stats_ranked(
        strat_ret,
        trade_mask,
        signal_exec,
        te["future_return_1d"].to_numpy(),
        up_move_band=best_band,
    )
    rolling_best_rows.append(
        {
            "window_id": window["window_id"],
            "train_start": str(window["train_start"].date()),
            "train_end": str(window["train_end"].date()),
            "test_start": str(window["test_start"].date()),
            "test_end": str(window["test_end"].date()),
            "features_used": len(bundle["selected_cols"]),
            **stats,
        }
    )

rolling_best_df = pd.DataFrame(rolling_best_rows)
rolling_path = output_dir / "stock_direction_v11_3_rolling_window_results.csv"
rolling_best_df.to_csv(rolling_path, index=False)
display(rolling_best_df.head(10).round(4))

print("Fitting best v11.3 config on final training split...")
final_bundle = fit_peak_model(
    train_df=final_train_df,
    stability_df=best_stability_df,
    top_k=int(best_cfg["top_k"]),
    hidden_layers=ast.literal_eval(best_cfg["hidden_layers"]),
    alpha_value=float(best_cfg["alpha_value"]),
    learning_rate=float(best_cfg["learning_rate"]),
    up_move_band=best_band,
)

print("Scoring final train and holdout splits...")
p_peak_train = score_peak_probabilities(final_bundle, final_train_df)
p_peak_test = score_peak_probabilities(final_bundle, final_test_df)
signal_train, prob_rank_train = select_top_ranked_signals(p_peak_train, budget_pct=float(best_cfg["rank_budget_pct"]))
signal_test, prob_rank_test = select_top_ranked_signals(p_peak_test, budget_pct=float(best_cfg["rank_budget_pct"]))

train_strat_ret, train_trade_mask, train_signal_exec = backtest_long_only(
    final_train_df["future_return_1d"].to_numpy(),
    signal_train,
    ONE_WAY_COST,
)
test_strat_ret, test_trade_mask, test_signal_exec = backtest_long_only(
    final_test_df["future_return_1d"].to_numpy(),
    signal_test,
    ONE_WAY_COST,
)

buyhold_train = final_train_df.copy()
buyhold_train["signal"] = 1
buyhold_train["strategy_return"] = buyhold_train["future_return_1d"]

buyhold_test = final_test_df.copy()
buyhold_test["signal"] = 1
buyhold_test["strategy_return"] = buyhold_test["future_return_1d"]

metrics_rows = [
    {"model": "BuyHold", "split": "train", **perf_stats_ranked(buyhold_train["strategy_return"], np.ones(len(buyhold_train), dtype=bool), np.ones(len(buyhold_train), dtype=int), buyhold_train["future_return_1d"], up_move_band=best_band)},
    {"model": "BuyHold", "split": "test", **perf_stats_ranked(buyhold_test["strategy_return"], np.ones(len(buyhold_test), dtype=bool), np.ones(len(buyhold_test), dtype=int), buyhold_test["future_return_1d"], up_move_band=best_band)},
    {"model": "PeakRank_MLP_v11_3", "split": "train", **perf_stats_ranked(train_strat_ret, train_trade_mask, train_signal_exec, final_train_df["future_return_1d"], up_move_band=best_band)},
    {"model": "PeakRank_MLP_v11_3", "split": "test", **perf_stats_ranked(test_strat_ret, test_trade_mask, test_signal_exec, final_test_df["future_return_1d"], up_move_band=best_band)},
]
metrics_df = pd.DataFrame(metrics_rows)
metrics_path = output_dir / "stock_direction_v11_3_metrics.csv"
metrics_df.to_csv(metrics_path, index=False)

test_predictions = final_test_df[["date", "future_return_1d", "abs_future_return_1d"]].copy()
test_predictions["target_big_up"] = (final_test_df["future_return_1d"] > best_band).astype(int)
test_predictions["p_peak_up"] = p_peak_test
test_predictions["prob_rank_desc"] = prob_rank_test
test_predictions["signal"] = signal_test
test_predictions["trade_executed"] = test_trade_mask
test_predictions["strategy_return"] = test_strat_ret
pred_path = output_dir / "stock_direction_v11_3_test_predictions.csv"
test_predictions.to_csv(pred_path, index=False)

selected_feature_rows = []
stability_lookup = best_stability_df.set_index("feature") if not best_stability_df.empty else pd.DataFrame()
for rank, feature in enumerate(final_bundle["selected_cols"], start=1):
    row = {
        "feature": feature,
        "selected_rank": rank,
        "up_move_band": best_band,
        "hidden_layers": best_cfg["hidden_layers"],
        "alpha_value": float(best_cfg["alpha_value"]),
        "learning_rate": float(best_cfg["learning_rate"]),
        "rank_budget_pct": float(best_cfg["rank_budget_pct"]),
    }
    if not best_stability_df.empty and feature in stability_lookup.index:
        stats = stability_lookup.loc[feature]
        if isinstance(stats, pd.DataFrame):
            stats = stats.iloc[0]
        row["stability_freq_top_n"] = float(stats["freq_top_n"])
        row["stability_coverage"] = float(stats["coverage"])
        row["stability_mean_rank"] = float(stats["mean_rank"])
        row["stability_mean_mi"] = float(stats["mean_mi"])
    else:
        row["stability_freq_top_n"] = np.nan
        row["stability_coverage"] = np.nan
        row["stability_mean_rank"] = np.nan
        row["stability_mean_mi"] = np.nan
    selected_feature_rows.append(row)

selected_features_df = pd.DataFrame(selected_feature_rows)
selected_features_path = output_dir / "stock_direction_v11_3_selected_features.csv"
selected_features_df.to_csv(selected_features_path, index=False)

display(metrics_df.round(4))
display(selected_features_df)

print("Preparing ranking report and plots...")
y_true_peak = test_predictions["target_big_up"].astype(int)
y_pred_peak = test_predictions["signal"].astype(int)
print("Classification report for large-up target on full holdout:")
print(classification_report(y_true_peak, y_pred_peak, digits=4, zero_division=0))

fig, axes = plt.subplots(1, 2, figsize=(15, 4))
train_equity = np.cumprod(1 + train_strat_ret)
test_equity = np.cumprod(1 + test_strat_ret)
buyhold_train_equity = np.cumprod(1 + final_train_df["future_return_1d"].to_numpy())
buyhold_test_equity = np.cumprod(1 + final_test_df["future_return_1d"].to_numpy())

axes[0].plot(final_train_df["date"], train_equity, label="PeakRank_MLP_v11_3", linewidth=2)
axes[0].plot(final_train_df["date"], buyhold_train_equity, label="BuyHold", linewidth=2, alpha=0.8)
axes[0].set_title("Train cumulative return")
axes[0].legend()

axes[1].plot(final_test_df["date"], test_equity, label="PeakRank_MLP_v11_3", linewidth=2)
axes[1].plot(final_test_df["date"], buyhold_test_equity, label="BuyHold", linewidth=2, alpha=0.8)
axes[1].set_title("Holdout cumulative return")
axes[1].legend()

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(15, 4))
ax.plot(test_predictions["date"], test_predictions["future_return_1d"], color="#4c78a8", linewidth=1.5, label="Future return 1d")
big_up_mask = test_predictions["target_big_up"] == 1
trade_mask = test_predictions["signal"] == 1
ax.scatter(
    test_predictions.loc[big_up_mask, "date"],
    test_predictions.loc[big_up_mask, "future_return_1d"],
    facecolors="none",
    edgecolors="#f58518",
    s=70,
    label="Large up day",
)
ax.scatter(
    test_predictions.loc[trade_mask, "date"],
    test_predictions.loc[trade_mask, "future_return_1d"],
    color="#54a24b",
    marker="^",
    s=60,
    label="Top-ranked long",
)
ax.axhline(best_band, color="#e45756", linestyle="--", linewidth=1, label=f"Large-up band = {best_band:.3f}")
ax.axhline(0.0, color="gray", linewidth=1)
ax.set_title("Holdout returns with top-ranked signals and large-up days")
ax.legend()
plt.tight_layout()
plt.show()

print(f"Saved search results to {search_path}")
print(f"Saved rolling results to {rolling_path}")
print(f"Saved metrics to {metrics_path}")
print(f"Saved test predictions to {pred_path}")
print(f"Saved selected features to {selected_features_path}")
# Out:
# Starting v11.3 rolling search with 144 candidates
# [Config 1/144] band=0.02, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2317, precision=0.3287, recall=0.0692, sel_ret=0.0045, active=0.0603
# [Config 2/144] band=0.02, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3947, precision=0.3593, recall=0.1188, sel_ret=0.0063, active=0.0922
# [Config 3/144] band=0.02, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2458, precision=0.3466, recall=0.1383, sel_ret=0.0023, active=0.1091
# [Config 4/144] band=0.02, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2044, precision=0.3253, recall=0.1860, sel_ret=0.0016, active=0.1580
# [Config 5/144] band=0.02, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2317, precision=0.3287, recall=0.0692, sel_ret=0.0045, active=0.0603
# [Config 6/144] band=0.02, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3947, precision=0.3593, recall=0.1188, sel_ret=0.0063, active=0.0922
# [Config 7/144] band=0.02, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2458, precision=0.3466, recall=0.1383, sel_ret=0.0023, active=0.1091
# [Config 8/144] band=0.02, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1674, precision=0.3198, recall=0.1814, sel_ret=0.0008, active=0.1580
# [Config 9/144] band=0.02, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2062, precision=0.3380, recall=0.0766, sel_ret=0.0037, active=0.0603
# [Config 10/144] band=0.02, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1648, precision=0.3250, recall=0.1113, sel_ret=0.0023, active=0.0922
# [Config 11/144] band=0.02, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0864, precision=0.2956, recall=0.1235, sel_ret=-0.0005, active=0.1091
# [Config 12/144] band=0.02, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1107, precision=0.2747, recall=0.1649, sel_ret=-0.0075, active=0.1580
# [Config 13/144] band=0.02, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1847, precision=0.3241, recall=0.0736, sel_ret=0.0030, active=0.0603
# [Config 14/144] band=0.02, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1706, precision=0.3250, recall=0.1113, sel_ret=0.0024, active=0.0922
# [Config 15/144] band=0.02, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0974, precision=0.3036, recall=0.1262, sel_ret=-0.0003, active=0.1091
# [Config 16/144] band=0.02, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1075, precision=0.2802, recall=0.1680, sel_ret=-0.0073, active=0.1580
# [Config 17/144] band=0.02, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0769, precision=0.2963, recall=0.0528, sel_ret=0.0031, active=0.0603
# [Config 18/144] band=0.02, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0849, precision=0.2824, recall=0.0859, sel_ret=0.0009, active=0.0922
# [Config 19/144] band=0.02, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1925, precision=0.3287, recall=0.1190, sel_ret=0.0036, active=0.1091
# [Config 20/144] band=0.02, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2229, precision=0.3309, recall=0.1788, sel_ret=0.0031, active=0.1580
# [Config 21/144] band=0.02, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0769, precision=0.2963, recall=0.0528, sel_ret=0.0031, active=0.0603
# [Config 22/144] band=0.02, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0849, precision=0.2824, recall=0.0859, sel_ret=0.0009, active=0.0922
# [Config 23/144] band=0.02, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1925, precision=0.3287, recall=0.1190, sel_ret=0.0036, active=0.1091
# [Config 24/144] band=0.02, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2229, precision=0.3309, recall=0.1788, sel_ret=0.0031, active=0.1580
# [Config 25/144] band=0.02, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1862, precision=0.3287, recall=0.0714, sel_ret=0.0025, active=0.0603
# [Config 26/144] band=0.02, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2587, precision=0.3417, recall=0.1140, sel_ret=0.0055, active=0.0922
# [Config 27/144] band=0.02, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2456, precision=0.3433, recall=0.1362, sel_ret=0.0053, active=0.1091
# [Config 28/144] band=0.02, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1571, precision=0.3012, recall=0.1714, sel_ret=0.0023, active=0.1580
# [Config 29/144] band=0.02, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1653, precision=0.3287, recall=0.0714, sel_ret=0.0020, active=0.0603
# [Config 30/144] band=0.02, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2982, precision=0.3509, recall=0.1186, sel_ret=0.0061, active=0.0922
# [Config 31/144] band=0.02, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2230, precision=0.3353, recall=0.1339, sel_ret=0.0045, active=0.1091
# [Config 32/144] band=0.02, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1571, precision=0.3012, recall=0.1714, sel_ret=0.0023, active=0.1580
# [Config 33/144] band=0.02, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.4467, precision=0.4861, recall=0.1106, sel_ret=0.0115, active=0.0603
# [Config 34/144] band=0.02, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.4531, precision=0.4019, recall=0.1442, sel_ret=0.0070, active=0.0922
# [Config 35/144] band=0.02, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3639, precision=0.4101, recall=0.1701, sel_ret=0.0053, active=0.1091
# [Config 36/144] band=0.02, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2411, precision=0.3667, recall=0.2142, sel_ret=0.0023, active=0.1580
# [Config 37/144] band=0.02, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.4448, precision=0.4861, recall=0.1106, sel_ret=0.0114, active=0.0603
# [Config 38/144] band=0.02, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.4605, precision=0.4019, recall=0.1442, sel_ret=0.0073, active=0.0922
# [Config 39/144] band=0.02, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3695, precision=0.4101, recall=0.1701, sel_ret=0.0055, active=0.1091
# [Config 40/144] band=0.02, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2411, precision=0.3667, recall=0.2142, sel_ret=0.0023, active=0.1580
# [Config 41/144] band=0.02, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0297, precision=0.3472, recall=0.0744, sel_ret=-0.0110, active=0.0603
# [Config 42/144] band=0.02, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0751, precision=0.3204, recall=0.1049, sel_ret=-0.0030, active=0.0922
# [Config 43/144] band=0.02, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1704, precision=0.3373, recall=0.1268, sel_ret=-0.0008, active=0.1091
# [Config 44/144] band=0.02, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.4065, precision=0.3642, recall=0.1983, sel_ret=0.0066, active=0.1580
# [Config 45/144] band=0.02, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0036, precision=0.3380, recall=0.0719, sel_ret=-0.0116, active=0.0603
# [Config 46/144] band=0.02, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1044, precision=0.3315, recall=0.1080, sel_ret=-0.0023, active=0.0922
# [Config 47/144] band=0.02, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1967, precision=0.3373, recall=0.1268, sel_ret=-0.0003, active=0.1091
# [Config 48/144] band=0.02, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.4107, precision=0.3605, recall=0.1922, sel_ret=0.0057, active=0.1580
# [Config 49/144] band=0.025, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0222, precision=0.1898, recall=0.0443, sel_ret=-0.0031, active=0.0603
# [Config 50/144] band=0.025, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0270, precision=0.1861, recall=0.0680, sel_ret=-0.0040, active=0.0922
# [Config 51/144] band=0.025, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0488, precision=0.1779, recall=0.0772, sel_ret=-0.0036, active=0.1091
# [Config 52/144] band=0.025, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1601, precision=0.2296, recall=0.1421, sel_ret=0.0008, active=0.1580
# [Config 53/144] band=0.025, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0222, precision=0.1898, recall=0.0443, sel_ret=-0.0031, active=0.0603
# [Config 54/144] band=0.025, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0270, precision=0.1861, recall=0.0680, sel_ret=-0.0040, active=0.0922
# [Config 55/144] band=0.025, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0418, precision=0.1779, recall=0.0772, sel_ret=-0.0033, active=0.1091
# [Config 56/144] band=0.025, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1552, precision=0.2296, recall=0.1421, sel_ret=0.0007, active=0.1580
# [Config 57/144] band=0.025, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0867, precision=0.2130, recall=0.0647, sel_ret=0.0016, active=0.0603
# [Config 58/144] band=0.025, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0314, precision=0.1917, recall=0.0849, sel_ret=-0.0027, active=0.0922
# [Config 59/144] band=0.025, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0136, precision=0.1991, recall=0.1056, sel_ret=-0.0031, active=0.1091
# [Config 60/144] band=0.025, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0898, precision=0.2179, recall=0.1629, sel_ret=-0.0015, active=0.1580
# [Config 61/144] band=0.025, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0644, precision=0.1991, recall=0.0591, sel_ret=-0.0000, active=0.0603
# [Config 62/144] band=0.025, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0314, precision=0.1917, recall=0.0849, sel_ret=-0.0027, active=0.0922
# [Config 63/144] band=0.025, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0136, precision=0.1991, recall=0.1056, sel_ret=-0.0031, active=0.1091
# [Config 64/144] band=0.025, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0898, precision=0.2179, recall=0.1629, sel_ret=-0.0015, active=0.1580
# [Config 65/144] band=0.025, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.3594, precision=0.1111, recall=0.0422, sel_ret=-0.0171, active=0.0603
# [Config 66/144] band=0.025, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.3267, precision=0.1333, recall=0.0641, sel_ret=-0.0118, active=0.0922
# [Config 67/144] band=0.025, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.3182, precision=0.1111, recall=0.0667, sel_ret=-0.0108, active=0.1091
# [Config 68/144] band=0.025, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.2466, precision=0.1525, recall=0.1095, sel_ret=-0.0077, active=0.1580
# [Config 69/144] band=0.025, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.3594, precision=0.1111, recall=0.0422, sel_ret=-0.0171, active=0.0603
# [Config 70/144] band=0.025, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.3267, precision=0.1333, recall=0.0641, sel_ret=-0.0118, active=0.0922
# [Config 71/144] band=0.025, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.3182, precision=0.1111, recall=0.0667, sel_ret=-0.0108, active=0.1091
# [Config 72/144] band=0.025, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.2466, precision=0.1525, recall=0.1095, sel_ret=-0.0077, active=0.1580
# [Config 73/144] band=0.025, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3291, precision=0.3935, recall=0.0986, sel_ret=0.0064, active=0.0603
# [Config 74/144] band=0.025, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3286, precision=0.3731, recall=0.1456, sel_ret=0.0077, active=0.0922
# [Config 75/144] band=0.025, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3543, precision=0.3776, recall=0.1643, sel_ret=0.0096, active=0.1091
# [Config 76/144] band=0.025, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3095, precision=0.3296, recall=0.2053, sel_ret=0.0069, active=0.1580
# [Config 77/144] band=0.025, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2860, precision=0.3935, recall=0.0986, sel_ret=0.0055, active=0.0603
# [Config 78/144] band=0.025, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3286, precision=0.3731, recall=0.1456, sel_ret=0.0077, active=0.0922
# [Config 79/144] band=0.025, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3543, precision=0.3776, recall=0.1643, sel_ret=0.0096, active=0.1091
# [Config 80/144] band=0.025, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3095, precision=0.3296, recall=0.2053, sel_ret=0.0069, active=0.1580
# [Config 81/144] band=0.025, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1407, precision=0.3287, recall=0.0708, sel_ret=0.0018, active=0.0603
# [Config 82/144] band=0.025, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0067, precision=0.2417, recall=0.0836, sel_ret=-0.0033, active=0.0922
# [Config 83/144] band=0.025, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0301, precision=0.2348, recall=0.0942, sel_ret=-0.0029, active=0.1091
# [Config 84/144] band=0.025, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0569, precision=0.2401, recall=0.1433, sel_ret=-0.0008, active=0.1580
# [Config 85/144] band=0.025, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1815, precision=0.3426, recall=0.0745, sel_ret=0.0031, active=0.0603
# [Config 86/144] band=0.025, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0102, precision=0.2417, recall=0.0836, sel_ret=-0.0027, active=0.0922
# [Config 87/144] band=0.025, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0226, precision=0.2348, recall=0.0942, sel_ret=-0.0026, active=0.1091
# [Config 88/144] band=0.025, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0634, precision=0.2401, recall=0.1433, sel_ret=-0.0006, active=0.1580
# [Config 89/144] band=0.025, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1287, precision=0.2500, recall=0.0572, sel_ret=-0.0015, active=0.0603
# [Config 90/144] band=0.025, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0558, precision=0.2083, recall=0.0766, sel_ret=-0.0026, active=0.0922
# [Config 91/144] band=0.025, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0682, precision=0.2255, recall=0.0930, sel_ret=-0.0014, active=0.1091
# [Config 92/144] band=0.025, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0433, precision=0.2469, recall=0.1504, sel_ret=-0.0022, active=0.1580
# [Config 93/144] band=0.025, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1287, precision=0.2500, recall=0.0572, sel_ret=-0.0015, active=0.0603
# [Config 94/144] band=0.025, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0558, precision=0.2083, recall=0.0766, sel_ret=-0.0026, active=0.0922
# [Config 95/144] band=0.025, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0682, precision=0.2255, recall=0.0930, sel_ret=-0.0014, active=0.1091
# [Config 96/144] band=0.025, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0311, precision=0.2414, recall=0.1466, sel_ret=-0.0024, active=0.1580
# [Config 97/144] band=0.03, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1280, precision=0.1389, recall=0.0352, sel_ret=-0.0061, active=0.0603
# [Config 98/144] band=0.03, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1516, precision=0.1148, recall=0.0416, sel_ret=-0.0054, active=0.0922
# [Config 99/144] band=0.03, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1150, precision=0.1389, recall=0.0587, sel_ret=-0.0038, active=0.1091
# [Config 100/144] band=0.03, top_k=8, hidden=(8,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1120, precision=0.1358, recall=0.0852, sel_ret=-0.0032, active=0.1580
# [Config 101/144] band=0.03, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1280, precision=0.1389, recall=0.0352, sel_ret=-0.0061, active=0.0603
# [Config 102/144] band=0.03, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1516, precision=0.1148, recall=0.0416, sel_ret=-0.0054, active=0.0922
# [Config 103/144] band=0.03, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1150, precision=0.1389, recall=0.0587, sel_ret=-0.0038, active=0.1091
# [Config 104/144] band=0.03, top_k=8, hidden=(8,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0941, precision=0.1414, recall=0.0880, sel_ret=-0.0030, active=0.1580
# [Config 105/144] band=0.03, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1355, precision=0.2269, recall=0.0899, sel_ret=-0.0107, active=0.0603
# [Config 106/144] band=0.03, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0315, precision=0.2731, recall=0.1303, sel_ret=-0.0019, active=0.0922
# [Config 107/144] band=0.03, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0330, precision=0.2665, recall=0.1477, sel_ret=-0.0015, active=0.1091
# [Config 108/144] band=0.03, top_k=8, hidden=(16,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1090, precision=0.2784, recall=0.2063, sel_ret=0.0004, active=0.1580
# [Config 109/144] band=0.03, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1355, precision=0.2269, recall=0.0899, sel_ret=-0.0107, active=0.0603
# [Config 110/144] band=0.03, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0315, precision=0.2731, recall=0.1303, sel_ret=-0.0019, active=0.0922
# [Config 111/144] band=0.03, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0330, precision=0.2665, recall=0.1477, sel_ret=-0.0015, active=0.1091
# [Config 112/144] band=0.03, top_k=8, hidden=(16,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1090, precision=0.2784, recall=0.2063, sel_ret=0.0004, active=0.1580
# [Config 113/144] band=0.03, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1952, precision=0.2037, recall=0.0457, sel_ret=0.0052, active=0.0603
# [Config 114/144] band=0.03, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3593, precision=0.2380, recall=0.0848, sel_ret=0.0087, active=0.0922
# [Config 115/144] band=0.03, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3530, precision=0.2374, recall=0.1026, sel_ret=0.0083, active=0.1091
# [Config 116/144] band=0.03, top_k=8, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2101, precision=0.2179, recall=0.1465, sel_ret=0.0035, active=0.1580
# [Config 117/144] band=0.03, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1952, precision=0.2037, recall=0.0457, sel_ret=0.0052, active=0.0603
# [Config 118/144] band=0.03, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3593, precision=0.2380, recall=0.0848, sel_ret=0.0087, active=0.0922
# [Config 119/144] band=0.03, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.3530, precision=0.2374, recall=0.1026, sel_ret=0.0083, active=0.1091
# [Config 120/144] band=0.03, top_k=8, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2101, precision=0.2179, recall=0.1465, sel_ret=0.0035, active=0.1580
# [Config 121/144] band=0.03, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2021, precision=0.1852, recall=0.0623, sel_ret=0.0093, active=0.0603
# [Config 122/144] band=0.03, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1097, precision=0.1463, recall=0.0736, sel_ret=0.0018, active=0.0922
# [Config 123/144] band=0.03, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0170, precision=0.1402, recall=0.0814, sel_ret=-0.0006, active=0.1091
# [Config 124/144] band=0.03, top_k=12, hidden=(8,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0807, precision=0.1364, recall=0.1065, sel_ret=-0.0018, active=0.1580
# [Config 125/144] band=0.03, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2021, precision=0.1852, recall=0.0623, sel_ret=0.0093, active=0.0603
# [Config 126/144] band=0.03, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1097, precision=0.1463, recall=0.0736, sel_ret=0.0018, active=0.0922
# [Config 127/144] band=0.03, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0170, precision=0.1402, recall=0.0814, sel_ret=-0.0006, active=0.1091
# [Config 128/144] band=0.03, top_k=12, hidden=(8,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0807, precision=0.1364, recall=0.1065, sel_ret=-0.0018, active=0.1580
# [Config 129/144] band=0.03, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0288, precision=0.0880, recall=0.0194, sel_ret=-0.0027, active=0.0603
# [Config 130/144] band=0.03, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0509, precision=0.0981, recall=0.0337, sel_ret=-0.0027, active=0.0922
# [Config 131/144] band=0.03, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0832, precision=0.1164, recall=0.0474, sel_ret=-0.0028, active=0.1091
# [Config 132/144] band=0.03, top_k=12, hidden=(16,), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1372, precision=0.1198, recall=0.0696, sel_ret=-0.0033, active=0.1580
# [Config 133/144] band=0.03, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0288, precision=0.0880, recall=0.0194, sel_ret=-0.0027, active=0.0603
# [Config 134/144] band=0.03, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0509, precision=0.0981, recall=0.0337, sel_ret=-0.0027, active=0.0922
# [Config 135/144] band=0.03, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0970, precision=0.1071, recall=0.0445, sel_ret=-0.0032, active=0.1091
# [Config 136/144] band=0.03, top_k=12, hidden=(16,), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.1372, precision=0.1198, recall=0.0696, sel_ret=-0.0033, active=0.1580
# [Config 137/144] band=0.03, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.1855, precision=0.2269, recall=0.0643, sel_ret=0.0045, active=0.0603
# [Config 138/144] band=0.03, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0816, precision=0.1944, recall=0.0821, sel_ret=-0.0003, active=0.0922
# [Config 139/144] band=0.03, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0596, precision=0.1799, recall=0.0935, sel_ret=-0.0008, active=0.1091
# [Config 140/144] band=0.03, top_k=12, hidden=(16, 8), alpha=0.001, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0185, precision=0.1698, recall=0.1276, sel_ret=-0.0012, active=0.1580
# [Config 141/144] band=0.03, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.05
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.2082, precision=0.2269, recall=0.0643, sel_ret=0.0049, active=0.0603
# [Config 142/144] band=0.03, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.08
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0671, precision=0.1852, recall=0.0788, sel_ret=-0.0006, active=0.0922
# [Config 143/144] band=0.03, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.1
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=0.0662, precision=0.1799, recall=0.0935, sel_ret=-0.0006, active=0.1091
# [Config 144/144] band=0.03, top_k=12, hidden=(16, 8), alpha=0.01, lr=0.001, budget=0.15
#   window 1/18
#   window 5/18
#   window 10/18
#   window 15/18
#   window 18/18
#   done: score=-0.0342, precision=0.1642, recall=0.1236, sel_ret=-0.0014, active=0.1580
#    up_move_band  top_k hidden_layers  alpha_value  learning_rate  \
# 0          0.02     12         (16,)        0.010          0.001
# 1          0.02     12         (16,)        0.001          0.001
# 2          0.02     12         (16,)        0.001          0.001
# 3          0.02     12         (16,)        0.010          0.001
# 4          0.02     12       (16, 8)        0.010          0.001
# 5          0.02     12       (16, 8)        0.001          0.001
# 6          0.02      8          (8,)        0.001          0.001
# 7          0.02      8          (8,)        0.010          0.001
# 8          0.02     12         (16,)        0.010          0.001
# 9          0.02     12         (16,)        0.001          0.001
#
#    rank_budget_pct  rolling_score  rolling_mean_cum_return  \
# 0             0.08       0.460525                 0.024403
# 1             0.08       0.453142                 0.022684
# 2             0.05       0.446700                 0.029522
# 3             0.05       0.444841                 0.029061
# 4             0.15       0.410716                 0.058731
# 5             0.15       0.406532                 0.054365
# 6             0.08       0.394742                 0.026019
# 7             0.08       0.394742                 0.026019
# 8             0.10       0.369541                 0.014617
# 9             0.10       0.363889                 0.013236
#
#    rolling_median_cum_return  rolling_mean_sharpe  rolling_mean_drawdown  \
# 0                   0.044301             1.054690              -0.061796
# 1                   0.044301             1.020291              -0.062176
# 2                   0.031688             0.961210              -0.037122
# 3                   0.031688             0.953704              -0.038879
# 4                   0.057862             0.695541              -0.085226
# 5                   0.057862             0.698575              -0.086629
# 6                   0.048017             0.773019              -0.054419
# 7                   0.048017             0.773019              -0.054419
# 8                   0.012290             0.665788              -0.085777
# 9                   0.012290             0.639118              -0.085777
#
#    rolling_mean_active_pct  rolling_mean_hit_rate  \
# 0                 0.092160               0.601852
# 1                 0.092160               0.592593
# 2                 0.060302               0.629630
# 3                 0.060302               0.629630
# 4                 0.157975               0.519136
# 5                 0.157975               0.522222
# 6                 0.092160               0.533333
# 7                 0.092160               0.533333
# 8                 0.109138               0.601852
# 9                 0.109138               0.593915
#
#    rolling_mean_precision_at_budget  rolling_mean_recall_at_budget  \
# 0                          0.401852                       0.144193
# 1                          0.401852                       0.144193
# 2                          0.486111                       0.110628
# 3                          0.486111                       0.110628
# 4                          0.360494                       0.192210
# 5                          0.364198                       0.198270
# 6                          0.359259                       0.118821
# 7                          0.359259                       0.118821
# 8                          0.410053                       0.170106
# 9                          0.410053                       0.170106
#
#    rolling_mean_selected_return  rolling_profitable_window_pct  n_windows
# 0                      0.007281                       0.722222         18
# 1                      0.006971                       0.722222         18
# 2                      0.011546                       0.611111         18
# 3                      0.011424                       0.611111         18
# 4                      0.005748                       0.888889         18
# 5                      0.006575                       0.833333         18
# 6                      0.006262                       0.777778         18
# 7                      0.006262                       0.777778         18
# 8                      0.005503                       0.611111         18
# 9                      0.005291                       0.611111         18
# Best v11.3 config: {'up_move_band': 0.02, 'top_k': 12, 'hidden_layers': '(16,)', 'alpha_value': 0.01, 'learning_rate': 0.001, 'rank_budget_pct': 0.08, 'rolling_score': 0.46052480269394513, 'rolling_mean_cum_return': 0.02440312780840773, 'rolling_median_cum_return': 0.04430067614062039, 'rolling_mean_sharpe': 1.0546897602034957, 'rolling_mean_drawdown': -0.06179632885894315, 'rolling_mean_active_pct': 0.09216029082704894, 'rolling_mean_hit_rate': 0.6018518518518517, 'rolling_mean_precision_at_budget': 0.40185185185185185, 'rolling_mean_recall_at_budget': 0.14419329523818689, 'rolling_mean_selected_return': 0.007281242288864854, 'rolling_profitable_window_pct': 0.7222222222222222, 'n_windows': 18}
# Re-running best v11.3 config across rolling windows...
#   best-config window 1/18
#   best-config window 5/18
#   best-config window 10/18
#   best-config window 15/18
#   best-config window 18/18
#    window_id train_start   train_end  test_start    test_end  features_used  \
# 0          1  2023-01-03  2024-01-02  2024-01-03  2024-04-02             12
# 1          2  2023-02-03  2024-02-02  2024-02-03  2024-05-02             12
# 2          3  2023-03-03  2024-03-02  2024-03-03  2024-05-31             12
# 3          4  2023-04-03  2024-04-02  2024-04-03  2024-07-02             12
# 4          5  2023-05-03  2024-05-02  2024-05-03  2024-08-02             12
# 5          6  2023-06-03  2024-06-02  2024-06-03  2024-08-30             12
# 6          7  2023-07-03  2024-07-02  2024-07-03  2024-10-02             12
# 7          8  2023-08-03  2024-08-02  2024-08-03  2024-11-01             12
# 8          9  2023-09-03  2024-09-02  2024-09-03  2024-12-02             12
# 9         10  2023-10-03  2024-10-02  2024-10-03  2025-01-02             12
#
#    cum_return  sharpe  max_drawdown  avg_daily_return  active_days  \
# 0      0.0812  2.1373       -0.0180            0.0013            5
# 1      0.0367  0.8043       -0.0565            0.0007            5
# 2     -0.0286 -0.4548       -0.0923           -0.0004            6
# 3      0.0337  0.7623       -0.0661            0.0006            6
# 4      0.1518  3.7513        0.0000            0.0023            6
# 5      0.1173  2.7950       -0.0254            0.0018            6
# 6      0.0978  4.0774        0.0000            0.0015            6
# 7      0.0459  1.2997       -0.0453            0.0007            6
# 8     -0.0684 -1.3179       -0.1016           -0.0010            6
# 9     -0.1346 -2.4420       -0.1683           -0.0022            6
#
#    active_pct  entries_exits  hit_rate_active  selected_mean_return  \
# 0      0.0806           10.0           0.6000                0.0172
# 1      0.0806           10.0           0.6000                0.0093
# 2      0.0952           12.0           0.3333               -0.0030
# 3      0.0952           12.0           0.5000                0.0073
# 4      0.0952           12.0           1.0000                0.0251
# 5      0.0952           12.0           0.8333                0.0200
# 6      0.0938           12.0           1.0000                0.0167
# 7      0.0938           12.0           0.8333                0.0089
# 8      0.0938           12.0           0.6667               -0.0100
# 9      0.0952           12.0           0.5000               -0.0220
#
#    selected_median_return  big_up_days  big_up_captured  recall_at_budget  \
# 0                  0.0035            9                2            0.2222
# 1                  0.0185           13                2            0.1538
# 2                 -0.0280           12                2            0.1667
# 3                 -0.0030           17                2            0.1176
# 4                  0.0193           18                3            0.1667
# 5                  0.0193           20                3            0.1500
# 6                  0.0166           19                2            0.1053
# 7                  0.0083           16                2            0.1250
# 8                  0.0070           21                1            0.0476
# 9                 -0.0164           24                1            0.0417
#
#    precision_at_budget
# 0               0.4000
# 1               0.4000
# 2               0.3333
# 3               0.3333
# 4               0.5000
# 5               0.5000
# 6               0.3333
# 7               0.3333
# 8               0.1667
# 9               0.1667
# Fitting best v11.3 config on final training split...
# Scoring final train and holdout splits...
#                 model  split  cum_return  sharpe  max_drawdown  \
# 0             BuyHold  train      1.9386  1.0064       -0.5377
# 1             BuyHold   test      0.4306  1.7463       -0.1650
# 2  PeakRank_MLP_v11_3  train      0.3546  0.7140       -0.1949
# 3  PeakRank_MLP_v11_3   test     -0.0029  0.0159       -0.0971
#
#    avg_daily_return  active_days  active_pct  entries_exits  hit_rate_active  \
# 0            0.0025          623      1.0000         1246.0           0.5152
# 1            0.0033          127      1.0000          254.0           0.5433
# 2            0.0006           50      0.0803          100.0           0.6000
# 3            0.0000           11      0.0866           22.0           0.6364
#
#    selected_mean_return  selected_median_return  big_up_days  big_up_captured  \
# 0                0.0025                  0.0013          172              172
# 1                0.0033                  0.0034           35               35
# 2                0.0081                  0.0149          172               22
# 3                0.0011                  0.0101           35                3
#
#    recall_at_budget  precision_at_budget
# 0            1.0000               0.2761
# 1            1.0000               0.2756
# 2            0.1279               0.4400
# 3            0.0857               0.2727
#                     feature  selected_rank  up_move_band hidden_layers  \
# 0            subm_posts_z20              1          0.02         (16,)
# 1         volume_z20_delta5              2          0.02         (16,)
# 2             ret_1d_delta1              3          0.02         (16,)
# 3    realized_vol_5d_delta5              4          0.02         (16,)
# 4    volume_vs_sma_20d_lag5              5          0.02         (16,)
# 5                    ret_5d              6          0.02         (16,)
# 6      subm_posts_z20_mean3              7          0.02         (16,)
# 7               ret_1d_lag2              8          0.02         (16,)
# 8   volume_vs_sma_20d_mean3              9          0.02         (16,)
# 9     subm_posts_z20_delta1             10          0.02         (16,)
# 10              ret_1d_lag5             11          0.02         (16,)
# 11          price_vs_sma_5d             12          0.02         (16,)
#
#     alpha_value  learning_rate  rank_budget_pct  stability_freq_top_n  \
# 0          0.01          0.001             0.08              0.611111
# 1          0.01          0.001             0.08              0.611111
# 2          0.01          0.001             0.08              0.611111
# 3          0.01          0.001             0.08              0.500000
# 4          0.01          0.001             0.08              0.444444
# 5          0.01          0.001             0.08              0.444444
# 6          0.01          0.001             0.08              0.388889
# 7          0.01          0.001             0.08              0.388889
# 8          0.01          0.001             0.08              0.388889
# 9          0.01          0.001             0.08              0.388889
# 10         0.01          0.001             0.08              0.333333
# 11         0.01          0.001             0.08              0.333333
#
#     stability_coverage  stability_mean_rank  stability_mean_mi
# 0                  1.0            18.000000           0.035504
# 1                  1.0            21.666667           0.032502
# 2                  1.0            26.111111           0.027874
# 3                  1.0            17.000000           0.028926
# 4                  1.0            27.666667           0.026330
# 5                  1.0            34.000000           0.021634
# 6                  1.0            29.166667           0.027689
# 7                  1.0            35.555556           0.016196
# 8                  1.0            44.555556           0.019196
# 9                  1.0            46.555556           0.014229
# 10                 1.0            27.277778           0.020156
# 11                 1.0            37.277778           0.015460
# Preparing ranking report and plots...
# Classification report for large-up target on full holdout:
#               precision    recall  f1-score   support
#
#            0     0.7241    0.9130    0.8077        92
#            1     0.2727    0.0857    0.1304        35
#
#     accuracy                         0.6850       127
#    macro avg     0.4984    0.4994    0.4691       127
# weighted avg     0.5997    0.6850    0.6210       127
# Saved search results to C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\data\equity_data\model_data\stock_direction_v11_3_search_results.csv
# Saved rolling results to C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\data\equity_data\model_data\stock_direction_v11_3_rolling_window_results.csv
# Saved metrics to C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\data\equity_data\model_data\stock_direction_v11_3_metrics.csv
# Saved test predictions to C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\data\equity_data\model_data\stock_direction_v11_3_test_predictions.csv
# Saved selected features to C:\Users\user\OneDrive\Documents\magisterka\praca magisterska\code\data\equity_data\model_data\stock_direction_v11_3_selected_features.csv
